# %%
# %run run_sweep.py
# Out:
# Starting run 0...
#   Initialization took 1.7s
# Starting Gillespie: max_time=0.01, num_sites=628
# Initial H atoms: 178, Initial H2: 0
# Step 0, time=0.000000, H_atoms=178, H2=0
# Step 1000, time=0.000000, H_atoms=152, H2=13
# Reached max_steps=2000, breaking
# Gillespie finished: 2000 steps, final_time=0.000000, H2_formed=13
#   Simulation took 720.5s
#   Total: 722.2s
# Aggregated simulation results saved to results/science_campaign_v1.csv

# %%
# %run run_sweep.py
# Out:
# Starting run 0...
# Building neighbor cache...
# Neighbor cache built: 2513 sites
#   Initialization took 32.5s
# Starting Gillespie: max_time=0.05, num_sites=2513
# Initial H atoms: 543, Initial H2: 0
# Step 0, time=0.000000, H_atoms=543, H2=0
# Step 1000, time=0.000000, H_atoms=493, H2=25
# Step 2000, time=0.000000, H_atoms=491, H2=26
# Step 3000, time=0.000000, H_atoms=491, H2=26
# Step 4000, time=0.000000, H_atoms=491, H2=26
# Reached max_steps=5000, breaking
# Gillespie finished: 5000 steps, final_time=0.000000, H2_formed=26
#   Simulation took 29.0s
#   Total: 61.4s
# Starting run 0...
# Building neighbor cache...
# Neighbor cache built: 2513 sites
#   Initialization took 32.4s
# Starting Gillespie: max_time=0.05, num_sites=2513
# Initial H atoms: 543, Initial H2: 0
# Step 0, time=0.000000, H_atoms=543, H2=0
# Step 1000, time=0.000000, H_atoms=479, H2=32
# Step 2000, time=0.000000, H_atoms=479, H2=32
# Step 3000, time=0.000000, H_atoms=475, H2=34
# ...
